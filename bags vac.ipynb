# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url = "https://www.flipkart.com/bags-wallets-belts/~cs-gq2abynb5b/pr?sid=reh&collection-tab-name=Bags+and+Luggage&p%5B%5D=facets.discount_range_v1%255B%255D%3D50%2525%2Bor%2Bmore&param=8&offer=nb%3Amp%3A04050b6d25%2Cnb%3Amp%3A042c5f9825%2Cnb%3Amp%3A04f3abdc27&ctx=...%3D&fm=neo%2Fmerchandising&iid=M_e100ea5f-1c3e-41b1-9500-d35eaf65b5ae_4.7PRY6960OYOA&ppt=None&ppn=None&ssid=vq38dqmtxc0000001653989119798&otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_4.dealCard.OMU_7PRY6960OYOA_3&otracker1=hp_omu_SECTIONED_manualRanking_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_3&cid=7PRY6960OYOA&p%5B%5D=facets.brand%255B%255D%3DAMERICAN%2BTOURISTER"

# %%
allow = requests.get(url)

# %%
print(allow)
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
product_name = soup.select(".IRpwTa")

# %%
product_name
# Out:
# [<a class="IRpwTa" href="/american-tourister-prime-nxt-laptop-backpack-01-black-32-l/p/itm22b027d80824f?pid=BKPFJHWKZ6HHFNAN&amp;lid=LSTBKPFJHWKZ6HHFNAN0K7UVJ&amp;marketplace=FLIPKART&amp;store=reh&amp;srno=b_1_1&amp;otracker=hp_omu_Deals%2Bof%2Bthe%2BDay_1_4.dealCard.OMU_7PRY6960OYOA_3&amp;otracker1=hp_omu_SECTIONED_manualRanking_neo%2Fmerchandising_Deals%2Bof%2Bthe%2BDay_NA_dealCard_cc_1_NA_view-all_3&amp;fm=organic&amp;iid=1c2eae31-88a3-4f5a-8317-c30617f2b335.BKPFJHWKZ6HHFNAN.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=6obz8p3uf40000001653989248862" rel="noopener noreferrer" target="_blank" title="Large 32 L Backpack PRIME NXT LAPTOP BACKPACK 01-BLACK">Large 32 L Backpack PRIME NXT LAPTOP BACKPACK 01-BLACK</a>,
# ...

# %%
product=[]

# %%
for item in product_name:
    product.append(item.text)

# %%
product
# Out:
# ['Large 32 L Backpack PRIME NXT LAPTOP BACKPACK 01-BLACK',
#  '58 L Strolley Duffel Bag - POLER WHEEL DUFFLE 65CM NAVY...',
#  'Large 31 L Backpack EDEN BACKPACK 01-BLACK/WHITE',
#  'Small 20 L Backpack ACE DAYPACK 02 - MAGENTA',
#  '29.5 L Laptop Backpack Tech Q',
#  '120 L Strolley Duffel Bag - Fieldbrook II - Black - Lar...']

# %%
product_rate=soup.select("._30jeq3")

# %%
product_rate
# Out:
# [<div class="_30jeq3">₹1,153</div>,
#  <div class="_30jeq3">₹1,870</div>,
#  <div class="_30jeq3">₹1,026</div>,
#  <div class="_30jeq3">₹611</div>,
#  <div class="_30jeq3">₹1,413</div>,
#  <div class="_30jeq3">₹1,699</div>]

# %%
rate=[]

# %%
for item in product_rate:
    rate.append(item.text)

# %%
rate
# Out:
# ['₹1,153', '₹1,870', '₹1,026', '₹611', '₹1,413', '₹1,699']

# %%
product=pd.DataFrame(product_name,columns=["product_names"])

# %%
product["price"]=product_rate

# %%
product.to_csv("CHARITHA VAC.csv")

# %%
product
# Out:
#                                        product_names     price
# 0  Large 32 L Backpack PRIME NXT LAPTOP BACKPACK ...  [₹1,153]
# 1  58 L Strolley Duffel Bag - POLER WHEEL DUFFLE ...  [₹1,870]
# 2   Large 31 L Backpack EDEN BACKPACK 01-BLACK/WHITE  [₹1,026]
# 3       Small 20 L Backpack ACE DAYPACK 02 - MAGENTA    [₹611]
# 4                      29.5 L Laptop Backpack Tech Q  [₹1,413]
# 5  120 L Strolley Duffel Bag - Fieldbrook II - Bl...  [₹1,699]
